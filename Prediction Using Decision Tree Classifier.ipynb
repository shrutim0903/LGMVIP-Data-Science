# %% [markdown]
# # LetsGrowMore - Jan2023- Data Science Intern
# Shruti Mandale

# %% [markdown]
# # Task 2.2 : Prediction Using Decision Tree Classifier

# %% [markdown]
# # DATA SET- https://bit.ly/3kXTdox

# %% [markdown]
# # Importing  Necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as sm
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from matplotlib.pyplot import rcParams

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # READING DATA

# %%
data = pd.read_csv("Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
# checking null values
data.isnull().sum()

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
sns.pairplot(data, hue = 'Species')

# %% [markdown]
# # heatmap with the co-relation of the dataset

# %%
sns.heatmap(data.corr(), annot= True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Splitting  and Processing Data

# %%
X = data.iloc[:, [0,1,2,3]]
y = data.Species
data.shape
# Out:
# (150, 6)

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [raw]
# Now that we have splitted our data, let us now build the Decision Tree
#
# Decision Tree

# %% [markdown]
# # Decision Tree

# %%
classifier = DecisionTreeClassifier(criterion='entropy')

# %%
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred_train = classifier.predict(X_train)
y_pred_test = classifier.predict(X_test)

# %%
# let us print the accuracy score for the tree model
print("The accuracy score for the built model is:",accuracy_score(y_test, y_pred_test))
# Out:
# The accuracy score for the built model is: 1.0

# %%
rcParams['figure.figsize'] = 80, 20
plot_tree(classifier, precision=5, rounded = False, filled = True)
# Out:
# [Text(1785.6, 906.0, 'X[3] <= 2.45\nentropy = 1.57573\nsamples = 120\nvalue = [46, 39, 35]'),
#  Text(892.8, 543.6, 'entropy = 0.0\nsamples = 46\nvalue = [46, 0, 0]'),
#  Text(2678.3999999999996, 543.6, 'X[0] <= 100.5\nentropy = 0.99789\nsamples = 74\nvalue = [0, 39, 35]'),
#  Text(1785.6, 181.19999999999993, 'entropy = 0.0\nsamples = 39\nvalue = [0, 39, 0]'),
#  Text(3571.2, 181.19999999999993, 'entropy = 0.0\nsamples = 35\nvalue = [0, 0, 35]')]

# %% [markdown]
# # changing Max Depth
